# %%
from src import matriz_aumentada, eliminacion_gaussiana

A = [
    [2, 1, -1],
    [1, 0, 2],
    [1, -2, 4]
    
]
b = [0, 5, 5]

Ab = matriz_aumentada(A, b) # type: ignore
eliminacion_gaussiana(Ab)
# Out:
# [02-18 16:48:57][INFO][lindm]
# [[  1.   0.   2.   5.]
#  [  0.   1.  -5. -10.]
#  [  0.  -2.   2.   0.]]
# [02-18 16:48:57][INFO][lindm]
# [[  1.   0.   2.   5.]
#  [  0.   1.  -5. -10.]
#  [  0.   0.  -8. -20.]]
# array([0. , 2.5, 2.5])
